# %%
# Ejemplo de diccionario
peliculas = {'Hellboy': 'Guillermo del Toro', 'Roma': 'Alfonso Cuarón'}
codigos = {'México': 52, 'Brasil': 55, 'Francia': 33}
print(____)
print(____)
for ____, ____ in codigos.____():
    print("%s -> %d" % (____, ____))

# %%
print('El director de Hellboy es: ' + peliculas['Hellboy'])

# %%
alumnos = {'Jesús': 10, 'Manuel': 7, 'Raúl': 8, 'Tania': 9}
print(alumnos)
alumnos['Jesús'] = 9
print(alumnos)
alumnos['Lili'] = 5
print(alumnos)
del alumnos['Manuel']
print(alumnos)

# %%
poblacion = {'Nuevo León': ____, 'Chiapas': ____, 
             'Guanajuato': ____, 'Puebla': ____,
             'Veracruz': ____, 'Jalisco': ____,
             'EdoMex': ____}

# %%
for estado in poblacion.____():
    print(estado, end = ' ')

# %%
for poblacion in poblacion.____():
    print(poblacion, end = ' ')

# %%
poblacion = {'Nuevo León': 5.12, 'Chiapas': 5.218, 
             'Guanajuato': 5.854, 'Puebla': 6.169,
             'Veracruz': 8.113, 'Jalisco': 8.256,
             'EdoMex': 16.19}

# %%
list(poblacion.____())

# %%
list(poblacion.____())

# %%
list(poblacion.____())

# %%
capitales1 = {'Brasil': 'Brasilia', 'Francia': 'París', 'México': 'CdMx'}
capitales2 = {'Brasil': 'Brasilia', 'EUA': 'Washington', 'México': 'CdMx'}
capitales3 = {'México': 'CdMx', 'Brasil': 'Brasilia', 'Francia': 'París'}
print(capitales1 ____ capitales2)
print(capitales1 ____ capitales3)
print(capitales2 ____ capitales3)

# %%
from ____ import ____
texto = ('Este texto tiene algunas palabras ' 
         'Este es otro texto con unas palabras diferentes')

contador = Counter(texto.____())
for palabra, cont in sorted(contador.____()):
    print(f'{palabra:<12}{cont}')

print('\nNúmero de palabras únicas:', len(contador.____()))

# %%
# diccionario vacio
dir_peliculas = {}
print(dir_peliculas)
# se añaden elementos al diccionario
dir_peliculas.____({'Cuarón':'Roma'})  
print(dir_peliculas)
dir_peliculas.____(Spielberg = 'E.T.')
print(dir_peliculas)

# %%
paises = {'México', 'EUA', 'Japón', 'México', 'Rusia'}
print(paises)

# %%
for pais in paises:
    print(pais.____(), end=' ')

# %%
numeros = ____(range(10)) + ____(range(5))
print(numeros)
mi_conjunto = ____(numeros)
print(mi_conjunto)

# %%
print('¿Los conjuntos son iguales?')
print({1, 2, 5} == {2, 1, 5})
print('¿Los conjuntos son diferentes?')
print({1, 2, 5} != {2, 1, 5})

# %%
# ¿Es {3, 5, 1} subconjunto propio de {1, 3, 5}?
print({1, 3, 5} < {3, 5, 1})
# ¿Es {1, 3, 5} subconjunto propio de {7, 3, 5, 1}
print({1, 3, 5} < {7, 3, 5, 1})
# ¿Es {1, 3, 5} subconjunto impropio de {3, 5, 1}
print({1, 3, 5} <= {3, 5, 1})
# ¿Es {1, 3} subconjunto impropio de {3, 5, 1}
print({1, 3} <= {3, 5, 1})

# %%
# ¿Es {1, 3, 5} superconjunto propio de {3, 5, 1}?
print({1, 3, 5} > {3, 5, 1})
# ¿Es {1, 3, 5} superconjunto propio de {3, 5, 1}?
print({1, 3, 5, 7} > {3, 5, 1})
# ¿Es {1, 3, 5} superconjunto impropio de {3, 5, 1}?
print({1, 3, 5} >= {3, 5, 1})
# ¿Es {1, 3, 5} superconjunto impropio de {3, 1}?
print({1, 3, 5} >= {3, 1})
# ¿Es {1, 3} superconjunto impropio de {3, 1, 7}?
print({1, 3} >= {3, 1, 7})

# %%
print({1, 3, 5} | {2, 3, 4})
print({1, 3, 5}.____([2, 3, 4]))

# %%
print({1, 3, 5} & {2, 3, 4})
print({1, 3, 5}.____([2, 3, 4]))

# %%
print({1, 3, 5} - {2, 3, 4})
print({1, 3, 5}.____([2, 3, 4]))

# %%
numeros = {1, 2, 3}
print(numeros)
numeros.____(17)
print(numeros)

# %%
numeros = {1, 2, 3}
print(numeros)
numeros.____(1)
print(numeros)

# %%
numeros = {1, 2, 3}
print(numeros)
numeros.____(2)
print(numeros)

# %%
numeros = {1, 2, 3}
print(numeros)
numeros.____()
print(numeros)

# %%
import numpy as np
numeros = np.____([0, 1, 1, 2, 3, 5, 8])
print(____(numeros))
numeros

# %%
np.____([[1, 2, 3], [4, 5, 6]])

# %%
import ____ as ____
ceros = np.____(5)
unos = np.____(8)
pers = np.____(5,2)
print(ceros)
print(unos)
print(pers)

# %%
mi_arreglo = np.____((3, 4), dtype=int)
print(mi_arreglo)

# %%
import ____ as ____
mi_arreglo = np.____(8)
mi_matriz = mi_arreglo.____(3,3)
print(mi_arreglo)
print(mi_matriz)

# %%
# Se crear un arreglo y se redimensiona
print(np.arange(1, 100001).____(100, 1000))

# %%
import ____
import ____ as ____

# %timeit dados_lista = [random.randrange(1, 7) for i in ____(0, 6_000_000)]

# %timeit dados_numpy = np.random.randint(1, 7, 6_000_000)

# %%
import ____ as ____ 

numeros1 = np.array([1, 2, 3, 4])
numeros2 = np.array([3, 4, 5, 6])
print(numeros1 * numeros2)

# %%
import numpy as np 

valor = 1
numeros1 = np.____([1, 2, 3, 4])
numeros2 = np.____([3, 4, 3, 6])
print(numeros1 == numeros2)
print(numeros1 > valor)

# %%
import numpy as np

arreglo = np.____([1, 4, 9, 16, 25])
lista = [1.1, 2.1, 3.2, 4.7, 5.1]

print(np.____(arreglo))
print(np.____(arreglo,lista))
print(np.____(lista))
print(np.____(arreglo, lista))

# %%
import numpy as np

calif = np.____([[87, 96, 70],
                  [100, 87, 90],
                  [94, 77, 90],
                  [100, 81, 82]])

calif[0, 1]

# %%
import numpy as np

a = np.arange(15)
print(a)
print(a[____])
print(a[____])
print(a[____])

# %%
import numpy as np

calif = np.array([[87, 96, 70],
                  [100, 87, 90],
                  [94, 77, 90],
                  [100, 81, 82]])

print(f'Las primeras dos filas son \n {calif[:2]}')
print(f'Las últimas tres filas son \n {calif[1:]}')
print(f'Las primeras dos columnas son \n {calif[:,:2]}')
print(f'Las últimas dos columnas son \n {calif[:,1:]}')

# %%
import numpy as np

arreglo = np.____(5)

copia1 = arreglo.____()
print(copia1)
arreglo *= 2
print(copia1)

copia2 = arreglo.____()
print(copia2)
arreglo *= 2
print(copia2)

# %%
arreglo1 = np.arange(10)
arreglo2 = arreglo1
print(id(arreglo1))
print(id(arreglo2))
arreglo3 = arreglo2.____()
print(id(arreglo3))
arreglo4 = arreglo2.____()
print(id(arreglo4))

arreglo2[1] = 100
print(arreglo1)

# %%
cadena1 = 'Esta es una cadena'
cadena2 = "Esta tambien es una cadena"
print(cadena1)
print(cadena2)

# %%
nombre = "Juan"
edad = 25 
print("Hola, %s. Tienes %d años." % (____, ____))

# %%
nombre = "Juan"
edad = 25 
print("Hola, {}. Tienes {} años.".____(____, ____))

# %%
nombre = "Juan"
edad = 25 
print(f"Hola, {____}. Tienes {____} años.")

# %%
cadena1 = f'Python '
cadena2 = f'es un gran lenguaje'
cadena3 = cadena1 + cadena2
cadena4 = cadena1 * 5
print(____)
print(____)

# %%
mi_cadena = f'      Python es un gran lenguaje        '
print(mi_cadena)
mi_cadena = mi_cadena.____()
print(mi_cadena)

# %%
mi_cadena = f'python Es un gran lenguaje'
print(mi_cadena.____())
print(mi_cadena.____())
print(mi_cadena.____())
print(mi_cadena.____())

# %%
oracion = 'El curso de Python para IA me encanta'
print(oracion.____('Python para'))
print(oracion.____('Python'))

# %%
mensaje = 'Hola, el curso de Python para IA me encanta'
print(mensaje)
print(mensaje.____())

# %%
paises = ['Rusia', 'Brasil', 'Sudáfrica', 'Alemania', 'Corea-Japón']
paises_mundial = ':'.____(____ for ____ in ____)
print(paises_mundial)

# %%
import ____

# Buscando coindicencias
cp = '09715'

print('Coincide') if re.____(cp, '09715') else print('No coincide')
print('Coincide') if re.____(cp, '09730') else print('No coincide')

# %%
print('Valido') if re.____('\d{5}', '002215') else print('Invalido')
print('Valido') if re.____('\d{5}', '9876') else print('Invalido')

# %%
import ____

frase = 'Python es un gran lenguaje'

reemplazo = re.____(' ', ',', frase)
print(reemplazo)
separacion = re.____('\s', frase)
print(separacion)
