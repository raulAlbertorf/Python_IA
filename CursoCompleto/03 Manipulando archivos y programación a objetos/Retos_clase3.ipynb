# %% [markdown]
# Reto 1

# %%
with open('estados.txt', ____='w') as ____:
    estados.write('Nuevo-León 5.12\n')
    estados.write('Chiapas 5.218\n')
    estados.write('Guanajuato 5.854\n')
    estados.write('Puebla 6.169\n')
    estados.write('Veracruz 8.113\n')
    estados.write('Jalisco 8.256\n')
    estados.write('EdoMex 16.19\n')

# %%
with open('estados.txt', mode='r') as estados:
    print(f'{"Nombre":<10}{"Población":>10}')
    for ____ in ____:
        nombre, poblacion = lectura.____()
        print(f'{nombre:<10}{poblacion:>10}')

# %% [markdown]
# Reto 2

# %%
estados = open('estados.txt', 'r')
archivo_temp = open('archivo_temp.txt', 'w')

# %%
with estados, archivo_temp:
    for ____ in ____:
        nombre, poblacion = lectura.____()
        if nombre != 'Veracruz':
            archivo_temp.____(lectura)
        else:
            nuevo_dato = ' '.____([nombre, '8.25'])
            archivo_temp.write(nuevo_dato + '\n')

# %%
import os
os.____('estados.txt')
os.____('archivo_temp.txt', 'estados.txt')

# %%
with open('estados.txt', mode='r') as estados:
    print(f'{"Nombre":<10}{"Población":>10}')
    for lectura in estados:
        nombre, poblacion = lectura.____()
        print(f'{nombre:<10}{poblacion:>10}')

# %% [markdown]
# Reto 3

# %%
dict_estados = {'estados': [
    {'estado': 'Nuevo-Leon', 'Poblacion': 5.12},
    {'estado': 'Chiapas', 'Poblacion': 5.218},
    {'estado': 'Guanajuato', 'Poblacion': 5.854},
    {'estado': 'Puebla', 'Poblacion': 6.169},
    {'estado': 'Veracruz', 'Poblacion': 8.113},
    {'estado': 'Jalisco', 'Poblacion': 8.256},
    {'estado': 'EdoMex', 'Poblacion': 16.19}]}

# %%
import ____

with open('estados.json', 'w') as ____:
    json.___(dict_estados, estados)

# %%
with open('estados.json', 'r') as ____:
    print(json.____(json.____(estados), indent=4))

# %% [markdown]
# Reto 4

# %%
import ____

try:
    valor = int(input('Dame un número entero: '))
    print(valor)
    num_factorial = math.____(valor)
except ValueError:
    print('Error: Factorial sólo acepta enteros positivos')
else:
    print(f'El factorial de {____} es {num_factorial}' )
finally:
    print('No olvide liberar recursos')

# %% [markdown]
# Reto 5

# %%
import ____ as ____

titanic = pd.read_csv('https://vincentarelbundock.github.io/' +
    'Rdatasets/csv/carData/TitanicSurvival.csv')

#titanic = pd.read_csv('TitanicSurvival.csv')

pd.set_option('precision', 2)  # Dos digitos para datos flotantes

# %%
titanic.____() # Mostrar los primeros 5 datos

# %%
titanic.____() # Mostrar los últimos 5 datos

# %%
# Asignan nuevos nombres a las columnas
titanic.____ = ['name', 'survived', 'sex', 'age', 'class']

# %%
# Estadisticas de los valores numericos
titanic._____()

# %%
(titanic.survived == 'yes').describe()

# %%
# Grafica el histograma 
# %matplotlib inline
histogram = titanic.____()

# %% [markdown]
# Reto 6

# %%
class ____:
    """Esta clase permite gestionar una cuenta"""
    def __init__(self, ____, ____):
        """Inicializa el objeto CuentaBancaria"""
        if nombre == '':
            raise ValueError('Nombre vacio')
        if saldo<0:
            raise ValueError('Saldo invalido')
        self.nombre = ____
        self.saldo = ____
    def depositar(self, deposito):
        self.saldo += deposito 
        print(f'Se actualizó el saldo de {self.nombre}')

# %%
nom_cliente = ____('Nombre del cliente: ')
sal_cliente = ____(input('Saldo del cliente: '))
cuenta = CuentaBancaria(no, sal_cliente)
cuenta.____(300)
print(cuenta.saldo)

# %% [markdown]
# Reto 7

# %%
class CuentaBancaria:
    """Esta clase permite gestionar una cuenta"""
    def __init__(self, ____, ____):
        """Inicializa el objeto CuentaBancaria"""
        if nombre == '':
            raise ValueError('Nombre vacio')
        if saldo<0:
            raise ValueError('Saldo invalido')
        self._nombre = ____
        self._saldo = ____
        print(f'Nuevo cliente {self._nombre} con saldo {self._saldo}')
    def depositar(self, deposito):
        print(f'Añadiendo saldo {deposito}')
        print(f'Saldo inicial: {self._saldo}') 
        self._saldo += deposito
        print(f'Saldo final: {self._saldo}')

# %%
nom_cliente = input('Nombre del cliente: ')
sal_cliente = float(input('Saldo del cliente: '))
cuenta = CuentaBancaria(____, ____)
cuenta.depositar(300)

# %%
print(cuenta.saldo)

# %% [markdown]
# Reto 8

# %%
class ____:
    """Esta clase es para implementar una persona"""
    
    def __init__(self, ____, ____, ____):
        """Inicializa el objeto Persona"""
        if type(nombre) != str or nombre == '' :
            raise ValueError('Nombre invalido')
        if edad < 0 and edad != int:
            raise ValueError('Edad invalida')
        if sexo not in ('M','F'):
            raise ValueError('Sexo invalido')
        self._nombre = ____
        self._edad = ____
    
    @____
    def nombre(self):
        return self._nombre
    
    @____
    def edad(self):
        return self._edad

# %%
class Estudiante(Persona):
    """Esta clase es para implementar una persona"""
    
    def __init__(self, nombre, edad, sexo, curso,telefono):
        Persona.__init__(self, ____, ____, ____)
        self._curso = curso
    
    @property
    def curso(self):
        return self._curso

# %%
alumno1 = Estudiante('José', 21, 'M', 'Python para IA',56456787)
print(f'El nombre del alumno es {alumno1.____}')
print(f'La edad del alumno es {alumno1.____}')
print(f'El alumno esta inscrito en {alumno1.____}')

# %% [markdown]
# Reto 9

# %%
class ____:
    """Esta clase es para implementar una persona"""

    def __init__(self, ____, ____, ____):
        """Inicializa el objeto Persona"""
        if type(nombre) != str or nombre == '' :
            raise ValueError('Nombre invalido')
        if edad < 0 and edad != int:
            raise ValueError('Edad invalida')
        if sexo not in ('M','F'):
            raise ValueError('Sexo invalido')
        self._nombre = nombre
        self._edad = edad
    
    @property
    def nombre(self):
        return self._nombre
    
    @property
    def edad(self):
        return self._edad

# %%
class ____:
    """Esta clase es para implementar un cliente"""
    
    def __init__(self, ____, ____, ____):
        self._nombre = nombre
        self._edad = edad
        self._telefono = telefono
    
    @____
    def ____(self):
        return f'El cliente se llama {self._nombre}'

    @____
    def edad(self):
        return self._edad

    @____
    def telefono(self):
        return self._telefono

# %%
class Estudiante(____, ____):
    """Esta clase es para implementar una persona"""
    
    def __init__(self, nombre, edad, sexo, curso,telefono):
        Persona.__init__(self, nombre, edad, sexo)
        Cliente.__init__(self, nombre, edad, telefono)
        self._curso = curso
    
    @property
    def curso(self):
        return self._curso

# %%
alumno1 = Estudiante('Jose', 21, 'M', 'Python para IA',56456787)
print(f'El nombre del alumno es {alumno1.____}')
print(f'La edad del alumno es {alumno1.____}')
print(f'El alumno esta inscrito en {alumno1.____}')
print(f'El telefono del alumno es {alumno1.____}')
cliente1 = Cliente('Manuel', 23, 55456789)
print(f'El nombre del cliente es {cliente1.____}')

# %% [markdown]
# Reto 10

# %%
class ____:
    """Esta clase es para implementar una persona"""
    
    def __init__(self, ____, _____, _____):
        """Inicializa el objeto Persona"""
        if type(nombre) != str or nombre == '' :
            raise ValueError('Nombre invalido')
        if edad < 0 and edad != int:
            raise ValueError('Edad invalida')
        if sexo not in ('M','F'):
            raise ValueError('Sexo invalido')
        self._nombre = nombre
        self._edad = edad
    
    @property
    def nombre(self):
        return self._nombre
    
    @property
    def edad(self):
        return self._edad

# %%
class Empleado(____):
    """Esta clase es para implementar un empleado"""

    def __init__(self, nombre, edad, sexo, clave_empl):
        Persona.__init__(self, nombre, edad, sexo)
        self._clave_empl = ____
 
    @____
    def nombre(self):
        print(f'El nombre del empleado es: ')
        return self._nombre

# %%
class Alumno(____):
    """Esta clase es para implementar un alumno"""

    def __init__(self, nombre, edad, sexo, num_alumno):
        ____.__init__(self, nombre, edad, sexo)
        self._num_alunmno = num_alumno
 
    @property
    def nombre(self):
        print(f'El nombre del alumno es: ')
        return self._nombre

# %%
print('Se instancia un nuevo alumno')
alumno = Alumno('Ramón', 21, 'M', 123456)
print('Se instancia un nuevo empleado')
empleado = Empleado('Diego', 35, 'M', 'B123456')
print(alumno.____)
print(empleado.____)

# %% [markdown]
# Reto 11

# %%
class Persona:
    """Esta clase es para implementar una persona"""

    def __init__(self, ____, ____, sexo
                 
          ):
        """Inicializa el objeto Persona"""
        if type(nombre) != str or nombre == '' :
            raise ValueError('Nombre invalido')
        if edad < 0 and edad != int:
            raise ValueError('Edad invalida')
        if sexo not in ('M','F'):
            raise ValueError('Sexo invalido')
        self._nombre = nombre
        self._edad = edad
    
    @property
    def nombre(self):
        return self._nombre
    
    @property
    def edad(self):
        return self._edad

# %%
class Programador(Persona):
    """Esta clase es para implementar un programador"""

    def __init__(self, nombre, edad, sexo, lenguaje):
        ____().__init__(nombre, edad, sexo)
        self._lenguaje = ____
 
    @property
    def nombre(self):
        print(f'El nombre del programador es: ')
        return self._nombre

    @property
    def lenguaje(self):
        print(f'El programador es especialista en ')
        return self._lenguaje

# %%
print('Se instancia un nuevo programador')
programador = Programador('Armando', 23, 'M', 'Python')
print(programador.____)
print(programador.____)
