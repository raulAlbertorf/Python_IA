# %% [markdown]
# Reto 1

# %%
def suma_poblacion(estados):
    suma = 0
    poblacion = {'Nuevo León': 5.12, 'Chiapas': 5.218, 
                 'Guanajuato': 5.854, 'Puebla': 6.169,
                 'Veracruz': 8.113, 'Jalisco': 8.256,
                 'EdoMex': 16.19}
    for ____,____ in poblacion.____():
      if estados[0] == est ____ estados[1] == est:
        suma += pob
    return ____

# %%
estados = []
estados.____(input('Dame el primer estado: '))
estados.____(input('Dame el segundo estado: '))
print('La sumas es: ' + str(____(estados)) + ' millones')

# %% [markdown]
# Reto 2

# %%
import ____ as ____
lista_promedios = []
alumnos = {'Martín': [____, ____, ____, ____], 'Armando': [____, ____, ____, ____],
           'Ernesto': [____, ____, ____, ____], 'Ignacio': [____, ____, ____, ____]}
for ____, ____ in alumnos.items():
    prom = st.mean(calif)
    print(f'El alumno {nombre} obtuvo {____} de promedio')
    lista_promedios.____(prom)
print(f'El promedio del grupo es {st.____(lista_promedios)}')

# %% [markdown]
# Reto 3

# %%
'''Programa para el conteo de frecuencias de palabras
utilizando diccionarios'''

texto = ('Este texto tiene algunas palabras ' 
         'Este es otro texto con unas palabras diferentes')

cont_pal = {}

# cuenta las veces que aparecen las palabras en los textos
for palabra in texto.____():
  if palabra in cont_pal:
    cont_pal[____] += 1 # Actualización de un par clave:valor
  else:
    cont_pal[____] = 1  # Nuevo par clave:valor

print(f'{"Palabra":<12}Conteo')

for ____, ____ in sorted(cont_pal.____()):
  print(f'{palabra:<12}{contador}')
print('\nNúmero de palabras únicas:', len(cont_pal))

# %% [markdown]
# Reto 4

# %%
# Programa de inscripción de alumnos
dic_alumnos = {}
num_alumnos = ____('¿Cuantos alumnos se inscriben? ')
# El if determina una cantidad invalida de alumnos
if(int(____) > 0):
    for i in ____(int(num_alumnos)):
        nombre = ____('Dame el nombre: ')
        edad = ____(____('Dame la edad: '))
        dic_alumnos.____({nombre:edad})
else:
    print('El número de alumnos no es válido')

# %% [markdown]
# Reto 5

# %%
nombres1 = ____(('Jesús', 'Karla', 'Manuel', 'Joel', 'Jimena'))
nombres2 = ____(('Jesús', 'Karla', 'Manuel', 'Joel', 'Jimena'))
nombres1.____('Rodrigo')
print('El contenido del conjunto es ')
print(____)
nombres2.____('Rodrigo')
print('El contenido del conjunto es ')
print(____)

# %% [markdown]
# Reto 6

# %%
import ____ as ____
arreglo = np.array([____, ____, ____, ____,
                    ____])
print(arreglo)
print(arreglo.____)
print(arreglo.____)
print(arreglo.____)
print(arreglo.____)
print(arreglo.____)

# %%
import ____ as ____
arreglo = np.array([____ for i in range(____)])
print(arreglo)
print(arreglo.____)
print(arreglo.____)
print(arreglo.____)
print(arreglo.____)
print(arreglo.____)

# %% [markdown]
# Reto 7

# %%
# Se importan bibliotecas
import ____ as ____
import ____ as ____

val_ini = ____('Dame el valor inicial: ')
val_fin = ____('Dame el valor final: ')
inter = ____('Dame el número de intervalos: ')

# Se crea el arreglo con numpy
t = np.____(float(val_ini), float(val_fin), int(inter))

# Se grafica el resultado
plt.____(t, np.____(t), 'r--')
plt.____()

# %% [markdown]
# Reto 8

# %%
# Se importa la biblioteca numpy
import ____ as ____

# Se define el arreglo con 100 numeros enteros
mi_arreglo = np.____(1, 51)

# El usuario da el valor
val = ____(____('Dame el valor: '))

# Se realizan las operaciones y se imprimen en pantalla
print(mi_arreglo ____ val)
print(mi_arreglo ____ val)
print(____ mi_arreglo)
print(mi_arreglo ____ val)
print(mi_arreglo ____ val)
print(mi_arreglo ____ val)
print(mi_arreglo ____ val)
print(mi_arreglo ____ val)

# %% [markdown]
# Reto 9

# %%
import ____ as ____

arreglo1 = np.array([])
arreglo2 = np.array([])

for i in range(____):
    for j in range(____):
        val = float(input('Dame la estatura: '))
        if i==1:
            arreglo1 = np.____(arreglo1, ____)
        else:
            arreglo2 = np.____(arreglo2, ____)
print(arreglo1 ____ arreglo2)
print(arreglo1 ____ arreglo2)
print(arreglo1 ____ arreglo2)
print(arreglo1 ____ arreglo2)
print(arreglo1 ____ arreglo2)
print(arreglo1 ____ arreglo2)

# %% [markdown]
# Reto 10

# %%
# Se importan bibliotecas
import ____ as ____

# Se crea el arreglo 
crp = np.array([____, ____, ____, ____, ____, ____, ____,
                ____, ____, ____])

# Métodos para hacer cálculos
print('La suma es: %0.4f' % crp.____())
print('El mínimo es: %0.4f' % crp.____())
print('El máximo es: %0.4f' % crp.____())
print('La media es: %0.4f' % crp.____())
print('La desviación estándar es: %0.4f' % crp.____())
print('La varianza es: %0.4f' % crp.____())

# %% [markdown]
# Reto 11

# %%
# Se importa la biblioteca numpy
import ____ as ____

# %%
# Se define la función


def ____():
    crp_tot = np.____([5.722, 3.992, 2.755, 2.338, 2.137, 1.984, 1.747,
                        1.647, 1.457, 1.438])
    for num, crp in enumerate(____, start=1):
        print(f'La empresa {____} tiene un crp de {____}')

# %%
# Se manda a llamar la función
CRP()

# %% [markdown]
# Reto 12

# %%
texto_ia = '''El objetivo último de la IA, lograr que una máquina 
tenga una inteligencia de tipo general similar a la humana, es uno 
de los objetivos más ambiciosos que se ha planteado la ciencia. 
Por su dificultad, es comparable a  explicar el origen de la vida, 
el origen del universo o conocer la estructura de la materia'''

ocurrencias = texto_ia.____('objetivo')
indice = texto_ia.____('IA')
inicia = texto_ia.____('El')
termina = texto_ia.____('universo')
nuevo_texto = texto_ia.____(' ','')

print(f'Ocurrecias de la palabra "objetivo": {____}')
print(f'Indice de la palabra "IA": {____}')
print(f'"El" es la palabra inicial: {____}')
print(f'"universo" es la palabra final: {____}')
print('El texto sin espacios es: ')
print(____)

# %% [markdown]
# Reto 13

# %%
mi_cadena = 'En el año 2019 , NETFLIX tiene 167.1 millones de suscriptores'
separados = mi_cadena.____()
digitos = [token.____() for token in separados]
alnum = [token.____() for token in separados]
alpha = [token.____() for token in separados]
decimal = [token.____() for token in separados]
numeric = [token.____() for token in separados]
minus = [token.____() for token in separados]
mayus = [token.____() for token in separados]

print(separados)
print(f'Las palabras con digitos son: {____}')
print(f'Las palabras con alfanumericos son: {____}')
print(f'Las palabras con alfabeticos son: {____}')
print(f'Las palabras con decimales son: {____}')
print(f'Las palabras con numericos son: {____}')
print(f'Las palabras con minusculas son: {____}')
print(f'Las palabras con mayusculas son: {____}')

# %% [markdown]
# Reto 14

# %%
import ____

celulares = 0
fijo = 0

frase = '''A nuestros estimados clientes, les proporcionamos nuestros números
celular: 5545221035 y 4675104590 ; fijo: 56460923'''
print(frase)
palabras = frase.____()
for palabra in palabras:
    if(re.____('\d{____}', palabra)):
        celulares += 1
    elif(re.____('\d{____}', palabra)):
        fijo += 1
print(f'La cantidad de telefonos celulares es {____}')
print(f'La cantidad de telefonos fijos es {____}')
