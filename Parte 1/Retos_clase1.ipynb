# %% [markdown]
# Reto 1

# %% [markdown]
# Reto 2

# %% [markdown]
# Reto 3

# %% [markdown]
# Reto 4

# %% [markdown]
# Reto 5

# %% [markdown]
# Reto 6

# %% [markdown]
# Reto 7

# %% [markdown]
# Reto 8

# %% [markdown]
# Reto 9

# %% [markdown]
# Reto 10

# %% [markdown]
# Reto 11

# %% [markdown]
# Reto 12

# %% [markdown]
# Reto 13

# %%
lista_netflix = [[15, 70.8], [16, 89.1], [17, 110.6], 
                 [18, 139.3], [19, 167.1]]
print('Los suscriptores de Netflix por año: ')
print(lista_netflix)
lista_netflix.____([20, 180.5])
print(lista_netflix)
nueva_lista = lista_netflix.____()
print(nueva_lista)
nueva_lista.____()
print(nueva_lista)
print(lista_netflix.____([15, 70.8]))
lista_netflix.____(nueva_lista)
print(lista_netflix)
print(lista_netflix.____([19, 167.1]))
lista_netflix.____(0, [14, 50.1])
print(lista_netflix)
lista_netflix.____(0)
print(lista_netflix)
lista_netflix.____([15, 70.8])
print(lista_netflix)
lista_netflix.____()
print(lista_netflix)
lista_netflix.____()
print(lista_netflix)

# %% [markdown]
# Reto 14

# %% [markdown]
# Reto 15

# %%
lista_nombres = [____, ____, ____, ____, ____]

def lista2tupla(lista_recibida):
    tupla_nombres = tuple(lista_recibida)
    print('La longitud es: ' + str(____(tupla_nombres)))
    print('El valor máximo es: ' + ____(tupla_nombres))
    print('El valor minimo es:' + ____(tupla_nombres))

print('La lista de nombres es: ' + str(lista_nombres))
lista2tupla(lista_nombres)
